# %%
#INTRODUCTION
#Excercise 1: Say "Hello, World!" With Python
if __name__ == '__main__':
    string_1= "Hello, "
    string_2= "World!"
    print(string_1+string_2)
# Out:
# Hello, World!

# %%
#INTRODUCTION
#Excercise 2: Arithmetic Operators
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
    result_1= a + b
    result_2= a - b
    result_3= a * b

    print(result_1)
    print(result_2)
    print(result_3)
# Out:
# Enter first number: 2
# Enter second number: 3
# 5
# -1
# 6

# %%
#INTRODUCTION
#Excercise 3: Division
if __name__ == '__main__':
    a = int(input())
    b = int(input())
    
    result = a//b
    result_1 = a/b
    print(result)
    print(result_1)
# Out:
# 4
# 3
# 1
# 1.3333333333333333

# %%
#INTRODUCTION
#Excercise 4: Loops
if __name__ == '__main__':
    n = int(input())
    
    for i in range(0,n):
        result = i**2
        print(result)
# Out:
# 5
# 0
# 1
# 4
# 9
# 16

# %%
#INTRODUCTION
#Excercise 5: Write a function
def is_leap(year):
    leap = False
    
    if year % 400 == 0:
        leap = True
    elif year % 100 == 0:
        leap = False
    elif year % 4 == 0:
        leap = True
    
    
    return leap

year = int(input())
print(is_leap(year))
# Out:
# 1990
# False

# %%
#INTRODUCTION
#Excercise 6: Print Function
if __name__ == '__main__':
    n = int(input())
    starting_point= 1 
    ending_point= 1+n 
    for numbers in range(starting_point,ending_point): 
        print(numbers, end='')
# Out:
# 3
# 123

# %%
#INTRODUCTION
#Excercise 7: If-Else
if __name__ == '__main__':
    n = int(input().strip())
    if (n%2!=0) or (n>=6 and n<=20):
        print("Weird")
    else:
        print("Not Weird")

# %%
#DATA TYPES
#Excercise 1: List Comprehension
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    x_1 = [i for i in range(x+1)]
    y_1 = [w for w in range (y+1)]
    z_1 = [e for e in range (z+1)]
    mylist = [[p,q,r] for p in x_1 for q in y_1 for r in z_1]
    result_array =[s for s in mylist if sum(s)!=n]
    print(result_array)

# %%
#DATA TYPES
#Excercise 2: Nested Lists
if __name__ == '__main__':
    dictionary = {}
    students = []
    grades = []
    for _ in range(int(input())):
        name = input()
        score = float(input())
        students.append(name)
        dictionary[name] = score
        grades.append(score)
    
    grades = list(dict.fromkeys(grades))
    low_score = sorted(grades)[1]
    list = []
    for i in students:
        if dictionary.get(i) == low_score:
            list.append(i)
    list_students = sorted(list)
    for w in list_students:
        print(w)

# %%
#DATA TYPES
#Excercise 3: Finding the percentage
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    name_marks = student_marks[query_name]
    total = sum(name_marks)
    output = total / len(name_marks)
    print("%.2f" %output)

# %%
#DATA TYPES
#Excercise 4: Lists
if __name__ == '__main__':
    N = int(input())
    list = []
    for l in range(0, N):
        my_query= input().split()
        if my_query[0] == 'print':
            print(list)
        elif my_query[0] == 'insert':
            list.insert(int(my_query[1]), int(my_query[2]))
        elif my_query[0] == 'remove':
            list.remove(int(my_query[1]))
        elif my_query[0] == 'append':
            list.append(int(my_query[1]))
        elif my_query[0] == 'sort':
            list.sort()
        elif my_query[0] == 'pop':
            list.pop()
        elif my_query[0] == 'reverse':
            list.reverse()

# %%
#DATA TYPES
#Excercise 5: Tuple
if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    print(hash(tuple(integer_list)))

# %%
#DATA TYPES
#Excercise 6: Find the Runner-up score
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    arr_new = list(set(arr))
    n1= max(arr_new[0],arr_new[1])
    n2= min(arr_new[0],arr_new[1])
    len_list= len(arr_new)
    for e in range(2,len_list):
        if n1 < arr_new[e]:
            n2= n1
            n1= arr_new[e]
        elif n2< arr_new [e]:
            n2 = arr_new[e]
    print(n2)

# %%
#STRINGS
#Excercise 1: split and join
def split_and_join(line):
    # write your code here
    return '-'.join(line.split())
    
if __name__ == '__main__':
    line = input()
    result = split_and_join(line)
    print(result)

# %%
#STRINGS
#Excercise 2: What's your name?
def print_full_name(first, last):
    # Write your code here
    str_1= "Hello {} {}! You just delved into python.".format(first,last)
    print(str_1)
if __name__ == '__main__':
    first_name = input()
    last_name = input()
    print_full_name(first_name, last_name)

# %%
#STRINGS
#Excercise 3: Mutations
def mutate_string(string, position, character):
    mylist= list(string)
    mylist[position]=character
    return ''.join(mylist)

if __name__ == '__main__':
    s = input()
    i, c = input().split()
    s_new = mutate_string(s, int(i), c)
    print(s_new)

# %%
#STRINGS
#Excercise 4: Find a String
def count_substring(string, sub_string):
    rlenght=len(string)
    plenght=len(sub_string)
    count=0
    
    for l in range(rlenght-plenght+1):
        if(string[l:(l+plenght)]==sub_string):
            count=count+1
    return count

if __name__ == '__main__':
    string = input().strip()
    sub_string = input().strip()
    
    count = count_substring(string, sub_string)
    print(count)

# %%
#STRINGS
#Excercise 5: string validators
if __name__ == '__main__':
    s = input()
    print(any(r.isalnum() for r in s))
    print(any(r.isalpha() for r in s))
    print(any(r.isdigit() for r in s))
    print(any(r.islower() for r in s))
    print(any(r.isupper() for r in s))

# %%
#STRINGS
#Excercise 6: text alignment
# Enter your code here. Read input from STDIN. Print output to STDOUT
thick= int(input())
o = 'H'

for s in range(thick):
    print((o*s).rjust(thick-1)+o+(o*s).ljust(thick-1))
    
for s in range(thick+1):
    print((o*thick).center(thick*2)+(o*thick).center(thick*6))
    
for s in range((thick+1)//2):
    print((o*thick*5).center(thick*6))
    
for s in range(thick+1):
    print((o*thick).center(thick*2)+(o*thick).center(thick*6))

for s in range(thick):
    print(((o*(thick-s-1)).rjust(thick)+o+(o*(thick-s-1)).ljust(thick)).rjust(thick*6))

# %%
#STRINGS
#Excercise 7: text wrap
import textwrap

def wrap(string, max_width):
    return '\n'.join(textwrap.wrap(string,max_width))

if __name__ == '__main__':
    string, max_width = input(), int(input())
    result = wrap(string, max_width)
    print(result)

# %%
#STRINGS
#Excercise 8: designer door mat
N,J= map(int,input().split(" "))

mid =int((J-7)/2)
m= int((J-3)/2)

for i in range(m,0,-3):
    u = int((J-2*i)/3)
    k=[]
    k.append("-"*i)
    k.append(".|."*u)
    k.append("-"*i)
    print("".join(k))
    
print("-"*mid+"WELCOME"+"-"*mid)

for i in range(3,m+1,3):
    u = int((J-2*i)/3)
    k=[]
    k.append("-"*i)
    k.append(".|."*u)
    k.append("-"*i)
    print("".join(k))

# %%
#STRINGS
#Excercise 9: string formatting
def print_formatted(number):
    # your code goes here
    f= len("{0:b}".format(number))
    
    for l in range(1,number+1):
        print("{0:{w}d} {0:{w}o} {0:{w}X} {0:{w}b}".format(l,w=f))
if __name__ == '__main__':
    n = int(input())
    print_formatted(n)

# %%
#STRINGS
#Excercise 10: alphabet rangoli
import string
alpha= string.ascii_lowercase

def print_rangoli(size):
    # your code goes here
    Q=[]
    for i in range(n):
        s= "-".join(alpha[i:n])
        Q.append((s[::-1]+s[1:]).center(4*n-3,"-"))
    print('\n'.join(Q[:0:-1]+Q))
    
if __name__ == '__main__':
    n = int(input())
    print_rangoli(n)

# %%
#STRINGS
#Excercise 11: capitalize
def solve(s):
    for x in s[:].split():
        s= s.replace(x,x.capitalize())
    return s

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    s = input()

    result = solve(s)

    fptr.write(result + '\n')

    fptr.close()

# %%
#STRINGS
#Excercise 12: the minion game
def minion_game(string):
    # your code goes here
    player_1= 0
    player_2= 0
    len_string= len(string)
    for i in range(len_string):
        if s[i] in "AEIOU":
            player_1 += len_string -i
        else:
            player_2 += len_string -i
    if player_1 > player_2:
        print("Kevin", player_1)
    elif player_2 > player_1:
        print("Stuart", player_2)
    elif player_1 == player_2:
        print("Draw")
    else:
        print("Draw")
if __name__ == '__main__':
    s = input()
    minion_game(s)

# %%
#STRINGS
#Excercise 13: merge the tools
def merge_the_tools(string, k):
    # your code goes here
    time=[]
    time_lenght= 0
    for n in string:
        time_lenght += 1
        if n not in time:
            time.append(n)
        if time_lenght == k:
            print(''.join(time))
            time= []
            time_lenght = 0
if __name__ == '__main__':
    string, k = input(), int(input())
    merge_the_tools(string, k)

# %%
#STRINGS
#Excercise 14: sWAP cASE
def swap_case(s):
    return s.swapcase()

if __name__ == '__main__':
    s = input()
    result = swap_case(s)
    print(result)

# %%
#SETS
#Excercise 1: Introduction to Sets
def average(array):
    # your code goes here
    arr= set(array)
    return sum(arr)/len(arr)
if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print(result)

# %%
#SETS
#Excercise 2: Symmetric difference
p,q = [set(input().split()) for _ in range(4)] [1::2]
print('\n'.join(sorted(p^q, key= int)))

# %%
#SETS
#Excercise 3: set.add()
w= int(input())
s=[input() for i in range(w)]
p= set(s)
print(len(p))

# %%
#SETS
#Excercise 4: discard(),remove(),pop()
n = int(input())
s = set(map(int, input().split()))

operations = int(input())

for x in range(operations):
  oper = input().split()
  if oper[0] == "remove":
    s.remove(int(oper[1]))
  elif oper[0] == "discard":
    s.discard(int(oper[1]))
  else:
    s.pop()
    
print(sum(s))

# %%
#SETS
#Excercise 5: Set.union()
m= []
u= int(input())
english= list(map(int, input().rstrip().split()))
z= int(input())
french= list(map(int, input().rstrip().split()))
for i in english:
    m.append(i)
    
for i in french:
    m.append(i)
    
s= set(m)
print(len(s))

# %%
#SETS
#Excercise 6: Set.intersection()
num1, st1, num2, st2 = (set(input().split()) for p in range(4))
print(len(st1.intersection(st2)))

# %%
#SETS
#Excercise 7: Set.difference()
n1 = int(input())
set_1 = set(map(int,input().split()))
n2 = int(input())
set_2 = set(map(int,input().split()))
print(len(set_1-set_2))

# %%
#SETS
#Excercise 8: Set.symmetric_difference()
_,n1= input(), set(input().split())
_,n2=input(), set(input().split())
print(len(n1.symmetric_difference(n2)))

# %%
#SETS
#Excercise 9: Set Mutations
_,K= (int(input()), set(map(int, input().split())))
B= int(input())
for _ in range(B):
    (command,newSet)= (input().split()[0], set(map(int, input().split())))
    getattr(K, command)(newSet)
print(sum(K))

# %%
#SETS
#Excercise 10: The Captain's Room
p=int(input())
l=list(map(int,input().split()))
s= set(l)
set1= set(x*p for x in s)
Value= (sum(set1)-sum(l))//(p-1)
print(Value)

# %%
#SETS
#Excercise 11: Check Subset
T= int(input())

for i in range(0, T):
    time= 0
    a, set_a = int(input()), set(map(int, input().split()))
    b, set_b = int(input()), set(map(int, input().split()))
    for i in set_a:
        if (i  in set_b):
            time= time+1
            continue
        else:
            print('False')
            break
    if (time==a):
        print('True')

# %%
#SETS
#Excercise 12: Check Strict Superset
a= set(map(int,input().split()))
flag=0
for i in range(int(input())):
    b=set(map(int,input().split()))
    if a.issuperset(b):
        continue
    else:
        print("False")
        flag=1
        break
if flag==0:
    print("True")

# %%
#SETS
#Excercise 13: No idea
p=map(int, input().split())
a=list(map(int, input().split()))
m=set(map(int, input().split()))
n=set(map(int, input().split()))
print(sum((i in m)-(i in n) for i in a))

# %%
#COLLECTIONS
#Excercise 1: DefaultDict Tutorial
from collections import defaultdict

N,M=map(int,input().split())

D=defaultdict(list)

for i in range(N):
    o=input().rstrip()
    D[o].append(i+1)
    
for i in range(M):
    s=input().rstrip()
    if s in D:
        print(' '.join(map(str,D[s])))
    else:
        print('-1')

# %%
#COLLECTIONS
#Excercise 2: Collections.namedtuple()
from collections import namedtuple

q= int(input())
fields= input().split()

total_marks= 0
for _ in range(q):
    stud=namedtuple('student', fields)
    MARKS, CLASS, NAME, ID = input().split()
    student= stud(MARKS, CLASS, NAME, ID)
    total_marks += int(student.MARKS)
print('{:.2f}'.format(total_marks/q))

# %%
#COLLECTIONS
#Excercise 3: Collections OrderedDict
from collections import OrderedDict
n= int(input())
d= OrderedDict()
d2={}

for _ in range(n):
    k= list(input().split())
    if " ".join(k[:len(k)-1]) in d2:
        d2[" ".join(k[:len(k)-1])]+= int(k[len(k)-1]) 
    else:
        d2[" ".join(k[:len(k)-1])]= int(k[len(k)-1]) 
    d[" ".join(k[:len(k)-1])] = k[len(k)-1]

for t in d:
    print(t,d2[t])

# %%
#COLLECTIONS
#Excercise 4:Word Order
from collections import Counter

n= int(input())
list= []

for i in range(n):
    list.append(input().strip())
    
count= Counter(list)

print(len(count))
print(*count.values())

# %%
#COLLECTIONS
#Excercise 5: Collections.deque()
from collections import deque

d= deque()

for _ in range(int(input())):
    oper, val, *args= input().split() + ['']
    eval(f'd.{oper} ({val})')
print(*d)

# %%
#COLLECTIONS
#Excercise 6: Company Logo
import math
import os
import random
import re
import sys

from collections import Counter

if __name__ == '__main__':
    s = input()
    w=sorted(s)

freq= Counter(list(w))
for k, v in freq.most_common(3):
    print(k, v)

# %%
#COLLECTIONS
#Excercise 7: Piling Up!
for t in range(int(input())):
    input()
    list = [int(o) for o in input().split()]
    list_1= list.index(min(list))
    left= list[:list_1]
    right= list[list_1+1:]
    if left == sorted(left, reverse=True) and right == sorted(right):
        print('Yes')
    else:
        print('No')

# %%
#COLLECTIONS
#Excercise 8: collections.Counter()
from collections import Counter

nshoes= input()
s= Counter(map(int, input().split()))
ncustomers= input()
n= int(ncustomers)

inc= 0

for k in range(n):
    size, price = map(int,input().split())
    if size in s and s[size]>0:
        s[size]-=1
        inc += price
print(inc)

# %%
#DATE AND TIME
#Excercise 1: Calendar Module
import calendar

days= ['MONDAY','TUESDAY', 'WEDNESDAY', 'THRUSDAY', 'FRIDAY', 'SATURDAY', 'SUNDAY']

month,day,year=map(int, input().split())
a=calendar.weekday(year, month, day)
print(days[a])

# %%
#DATE AND TIME
#Excercise 2: Time Delta--> found on the internet GitHub
import math
import os
import random
import re
import sys
from datetime import datetime
# Complete the time_delta function below.
def time_delta(t1, t2):
    time_format = '%a %d %b %Y %H:%M:%S %z'
    t1 = datetime.strptime(t1, time_format)
    t2 = datetime.strptime(t2, time_format)
    return str(int(abs((t1-t2).total_seconds())))   

if __name__ == '__main__':
    fptr = open(os.environ['OUTPUT_PATH'], 'w')

    t = int(input())

    for t_itr in range(t):
        t1 = input()

        t2 = input()

        delta = time_delta(t1, t2)

        fptr.write(delta + '\n')

    fptr.close()

# %%
#EXCEPTIONS only excercise
for i in range (int(input())):
    try:
        s,t= map(int,input().split())
        print(s//t)
    except Exception as e:
        print("Error Code:", e)

# %%
#BUILT-INS
#Excercise 1: Zipped!
f= input().split()
y=[]
for i in range(int(f[1])):
    s=map(float,input().split())
    y.append(s)
for i in range(int(f[1])):
    k=zip(*y)
p=list(k)
for i in p:
    print(sum(i)/int(f[1]))

# %%
#BUILT-INS
#Excercise 2: Athlete Sort
import math
import os
import random
import re
import sys

from collections import OrderedDict

if __name__ == '__main__':
    nm = input().split()

    n = int(nm[0])

    m = int(nm[1])

    arr = []

    for _ in range(n):
        arr.append(list(map(int, input().rstrip().split())))

    k = int(input())
    newdict= OrderedDict()
    
    for i in range(0,n):
        newdict[i]=arr[i]
        
    r= sorted(newdict.items(),key=lambda x:(x[1][k], x[0]))
    
    for i in r:
        print(*i[1])

# %%
#BUILT-INS
#Excercise 3: ginortS
s=input()
u=[]; l=[];do=[]; de=[]
for i in s:
    if i.isupper():
        u.append(i)
    elif i.islower():
        l.append(i)
    elif i.isdigit():
        if int(i)%2==0:
            de.append(i)
        else:
            do.append(i)
            
u.sort();l.sort();do.sort();de.sort()
dd= ""
for x in l:
    dd+=x
for x in u:
    dd+=x
for x in do:
    dd+=x
for x in de:
    dd+=x
print(dd)

# %%
#PYTHON FUNCTIONALS only excercise copied from Hackerrank Forum
cube = lambda x: x*x*x# complete the lambda function 

import sys

def fibonacci(n):
    # return a list of fibonacci numbers
    if n==0:
        return []
    elif n==1:
        return [0]
    elif n==2:
        return [0,1]
    else:
        a=fibonacci(n-1)
        a.append(a[-2]+a[-1])
        return a
    # return a list of fibonacci numbers

if __name__ == '__main__':
    n = int(input())
    print(list(map(cube, fibonacci(n))))

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 1:
regex_pattern = r"[.,]+"	# Do not delete 'r'.

import re
print("\n".join(re.split(regex_pattern, input())))

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 2: Group() Groups() Groupdict()
import re

exp= r"([a-zA-Z0-9])\1+"
m= re.search(exp,input())
if m:
    print(m.group(1))
else:
    print(-1)

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 3: re.findall()
import re
stor= re.findall(r'(?<=[qwrtypsdfghjklzxcvbnm])([aeiou]{2,})(?=[qwrtypsdfghjklzxcvbnm])', input().strip(), re.IGNORECASE)
if stor:
    for i in stor:
        print(i)
else:
    print(-1)

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 4: Re.start() & Re.end()
import re
s, k= input(), input()
match= re.finditer(r'(?=(' +k+ '))', s)
amatch= False
for m in match:
    amatch = True
    print((m.start(1), m.end(1)-1))
if amatch == False:
    print((-1, -1))

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 5:Regex Substitution
import re
for _ in range(int(input())):
    v=input()
    time=0
    while(time!=v):
        time=v
        v= re.sub(r"( && )", ' and ',v)
        v= re.sub(r"( \|\| )", ' or ',v)
    print(v)

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 6: Validating Roman Numerals
regex_pattern = r"^(M{0,3})(C{0,3}|CD|D|DC|DCC|DCCC|CM)(X{0,3}|XL|L|LX|LXX|LXXX|XC)(I{0,3}|IV|V|VI|VII|VIII|IX)$"	# Do not delete 'r'.

import re
print(str(bool(re.match(regex_pattern, input()))))

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 7: Validating Phone Number
import re
n=int(input())
for i in range(n):
    num=input()
    if len(num)==10:
        if re.search('[789]\d{9}', num):
            print('YES')
        else:
            print('NO')
            
    else:
        print('NO')

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 8: Validating and parsing email address copied from hackerrank
import re
from email.utils import *
for i in range(int(input())):
    email = parseaddr(input())
    # print email[1]
    # \w is equivalent to a-zA-Z_
    if bool(re.search(r'^[a-zA-Z][\w\-\.]*@[A-Za-z]+\.[a-zA-Z]{1,3}$', email[1])):
        print (formataddr(email))

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 9:Hex Color Code
import re
N=int(input())

for _ in range(N):
    inp= input()
    if(bool(re.search(r"^#", inp))==False):
        q= re.findall(r"#[A-Fa-f0-9]{6}|#[A-Fa-f0-9]{3}", inp)
        if(q!=[]):
            print(*q,sep="\n")

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 10:HTML Parser (Part-1) copied from hackerrank
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print ('Start :',tag)
        for attr in attrs:
                print ('->',' > '.join(map(str,attr)))
    def handle_endtag(self, tag):
        print ('End   :',tag)
    def handle_startendtag(self, tag, attrs):
        print ('Empty :',tag)
        for attr in attrs:
                print ('->',' > '.join(map(str,attr)))

html = ""
for i in range(int(input())):
    html += input()
                    
                
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 11:HTML Parser (Part-2)
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_data(self, data):
        if(data!="\n"):
            print(">>> Data")
            print(data)
    def handle_comment(self, data):
        list= data.split("\n")
        if(len(list)==1):
            print(">>> Single-line Comment")
            print(list[0])
        else:
            print(">>> Multi-line Comment")
            print(*list, sep="\n")
              
  
html = ""       
for i in range(int(input())):
    html += input().rstrip()
    html += '\n'
    
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 12: Detect HTML Tags, Attributes and Attribute Values
from html.parser import HTMLParser

class MyHTMLParser(HTMLParser):
    def handle_starttag(self, tag, attrs):
        print(tag)
        [print('-> {} > {}'.format(*attr)) for attr in attrs]
        
html= '\n'.join([input() for _ in range(int(input()))])
parser = MyHTMLParser()
parser.feed(html)
parser.close()

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 13: Validating UID copied from hackerrank
import re
for i in range(int(input())):
    N = input().strip()
    if N.isalnum() and len(N) == 10:
        if bool(re.search(r'(.*[A-Z]){2,}',N)) and bool(re.search(r'(.*[0-9]){3,}',N)):
            if re.search(r'.*(.).*\1+.*',N):
                print ('Invalid')
            else:
                print ('Valid')    
        else:
            print ('Invalid')
    else:
        print ('Invalid')

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 14: Validating Credit Card Numbers
import re
tester= re.compile(r"^" r"(?!.*(\d)(-?\1){3})" r"[456]" r"\d{3}" r"(?:-?\d{4}){3}" r"$")

for _ in range(int(input().strip())):
    print("Valid" if tester.search(input().strip()) else "Invalid")

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 15: Validating Postal Codes
regex_integer_in_range = r"^[1-9][\d]{5}$"	# Do not delete 'r'.
regex_alternating_repetitive_digit_pair = r"(\d)(?=\d\1)"	# Do not delete 'r'.

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 16: Matrix script
import math
import os
import random
import re
import sys

first_multiple_input = input().rstrip().split()

n = int(first_multiple_input[0])

m = int(first_multiple_input[1])

matrix = []
time= []
for _ in range(n):
    matrix_item = input()
    matrix.append(matrix_item)
    
for o in range(m):
    for u in matrix:
        time.append(u[o])
time= "".join(time)

t= re.sub(r"(?<=[A-Za-z0-9])[!,@,#,$,%,&,\s]+(?=[A-Za-z0-9])"," ", time)
print(t)

# %%
#REGEX AND PARSING CHALLENGES
#Excercise 17:Detect Floating Point Number
import re
n= int(input())
for i in range(n):
    if re.search('^[+-]?[0-9]*\.[0-9]*$', input()):
        print("True")
    else:
        print("False")

# %%
#XML
#Excercise 1: XML 1 - Find the Score
import sys
import xml.etree.ElementTree as etree

def get_attr_number(node):
    # your code goes here
    return(len(node.attrib)+ sum(get_attr_number(child) for child in node))

if __name__ == '__main__':
    sys.stdin.readline()
    xml = sys.stdin.read()
    tree = etree.ElementTree(etree.fromstring(xml))
    root = tree.getroot()
    print(get_attr_number(root))

# %%
#XML
#Excercise 2: XML2 Find The Maximum Depth
import xml.etree.ElementTree as etree

maxdepth = 0
def depth(elem, level):
    global maxdepth
    # your code goes here
    if(len(elem.findall(".//")) >0):
        level= level+1
        if (level >= maxdepth):
            maxdepth= level+1
        for i in elem:
            depth(i,level)
    
if __name__ == '__main__':
    n = int(input())
    xml = ""
    for i in range(n):
        xml =  xml + input() + "\n"
    tree = etree.ElementTree(etree.fromstring(xml))
    depth(tree.getroot(), -1)
    print(maxdepth)

# %%
#CLOSURE AND DECORATIONS
#Excercise 1:standardize mobile number using decorators
def wrapper(f):
    def fun(l):
        time=[]
        for i in range(len(l)):
            g= int(l[i][-10:-5])
            h= int(l[i][-5:])
            time.append("+91 "+ str(g) + " "+ str(h))
        f(time)
        # complete the function
    return fun

@wrapper
def sort_phone(l):
    print(*sorted(l), sep='\n')

if __name__ == '__main__':
    l = [input() for _ in range(int(input()))]
    sort_phone(l)

# %%
#CLOSURE AND DECORATIONS
#Excercise 2: Decorators 2 Name Directory
import operator

def person_lister(f):
    def inner(people):
        return map(f, sorted(people, key= lambda x: int(x[2])))
        # complete the function
    return inner

@person_lister
def name_format(person):
    return ("Mr. " if person[3] == "M" else "Ms. ") + person[0] + " " + person[1]

if __name__ == '__main__':
    people = [input().split() for i in range(int(input()))]
    print(*name_format(people), sep='\n')

# %%
#NUMPY
#Excercise 1: Arrays
import numpy

def arrays(arr):
    array= numpy.array(arr, float)
    return array[::-1]
    # complete this function
    # use numpy.array

arr = input().strip().split(' ')
result = arrays(arr)
print(result)

# %%
#NUMPY
#Excercise 2:Shape and Reshape
import numpy

l=list(map(int,input().split()))
array= numpy.array(l)
print(numpy.reshape(array, (3,3)))

# %%
#NUMPY
#Excercise 3:Transpose and Flatten
import numpy

n,m=map(int, input().split())
b=[]
for i in range(n):
    m= list(map(int,input().split()))
    b.append(m)
nw_arr=numpy.array(b)
print(numpy.transpose(nw_arr))
print(nw_arr.flatten())

# %%
#NUMPY
#Excercise 4: Concatenate
import numpy

n,m,p=map(int, input().split())
a=[]
for i in range(n):
    s=list(map(int,input().split()))
    a.append(s)
nw_arr=numpy.array(a)
b=[]
for i in range(m):
    k=list(map(int, input().split()))
    b.append(k)
new_array=numpy.array(b)
print(numpy.concatenate((nw_arr, new_array)))

# %%
#NUMPY
#Excercise 5:Zero and Ones
import numpy as np

num= tuple(map(int, input().split()))
print(np.zeros(num, dtype=np.int))
print(np.ones(num,dtype=np.int))

# %%
#NUMPY
#Excercise 6:Eye and identity
import numpy as np

n,m=map(int, input().split())
np.set_printoptions(sign=" ")
print(np.eye(n,m))

# %%
#NUMPY
#Excercise 7:Array Matematics
import numpy

n,m = map(int, input().split())
a,b = (numpy.array([input().split() for _ in range (n)], dtype= int) for _ in range(2))
print(a+b, a-b, a*b, a//b, a%b, a**b, sep='\n')

# %%
#NUMPY
#Excercise 8:Floor, Ceil and Rint
import numpy

numpy.set_printoptions(sign=" ")
a= numpy.array(input().split(), float)

print(numpy.floor(a))
print(numpy.ceil(a))
print(numpy.rint(a))

# %%
#NUMPY
#Excercise 9: Sum and Prod
import numpy

n, m=map(int, input().split())
o= numpy.array([input().split() for _ in range(n)], int)
print(numpy.prod(numpy.sum(o, axis= 0), axis=0))

# %%
#NUMPY
#Excercise 10: Min and Max
import numpy

print(numpy.max(numpy.min(numpy.array([input().split() for _ in range(int(input().split()[0]))], int), axis=1)))

# %%
#NUMPY
#Excercise 11: Mean, Variance and Standard Deviation
import numpy

n, m= list(map(int, input().split()))
arr= []
for i in range(0,n):
    arr.append(list(map(int,input().split())))
arr= numpy.array(arr)

print(numpy.mean(arr, axis= 1))
print(numpy.var(arr, axis= 0))
print(round(numpy.std(arr),11))

# %%
#NUMPY
#Excercise 12:Dot and Cross
import numpy

n= int(input())
a=[]
for i in range(0,n):
    a.append(list(map(int, input().split())))
a=numpy.array(a)
b=[]
for i in range(0,n):
    b.append(list(map(int, input().split())))
b=numpy.array(b)

print(numpy.dot(a,b))

# %%
#NUMPY
#Excercise 13:Inner and Outer
import numpy 
p= numpy.array(input().split(), int)
q= numpy.array(input().split(), int)
print(numpy.inner(p,q), numpy.outer(p,q), sep='\n')

# %%
#NUMPY
#Excercise 14: Polynomials
import numpy

l= list(map(float,input().split()))
x= int(input())
print(numpy.polyval(l,x))

# %%
#NUMPY
#Excercise 15: Linear Algebra
import numpy

a=[]
for i in range(int(input())):
    m=list(map(float,input().split()))
    a.append(m)
nw_arr=numpy.array(a)
val=round(numpy.linalg.det(a),2)
print(val)
